# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv("train.csv")

# %%
df.shape
# Out:
# (1628, 29)

# %%
# df.isnull().any()

# %%
left=df[df['Attrition']==1]
left.shape[0]
# Out:
# 785

# %%
retained=df[df['Attrition']==0]
retained.shape[0]
# Out:
# 843

# %%
# df.dtypes

# %%
df.groupby('Attrition').mean()
# Out:
#                     Id        Age  DistanceFromHome  Education  \
# Attrition
# 0           499.385528  37.480427          8.860024   2.925267
# 1          1152.896815  33.675159         10.675159   2.840764
#
#            EmployeeNumber  EnvironmentSatisfaction  JobInvolvement  \
# Attrition
# 0             1030.077106                 2.767497        2.763938
# 1              969.745223                 2.515924        2.528662
#
#            JobSatisfaction  MonthlyIncome  NumCompaniesWorked  ...  \
# Attrition                                                      ...
# 0                 2.795967    6792.187426            2.676157  ...
# 1                 2.471338    4704.484076            2.853503  ...
#
#            PerformanceRating  StockOptionLevel  TotalWorkingYears  \
# Attrition
# 0                   3.151839          0.838671          11.846975
# 1                   3.159236          0.535032           7.910828
#
# ...

# %%
# pd.crosstab(df.JobRole,df.Attrition).plot(kind='bar')

# %%
# pd.crosstab(df.BusinessTravel,df.Attrition).plot(kind='bar')

# %%
# pd.crosstab(df.EducationField,df.Attrition).plot(kind='bar')

# %%
# pd.crosstab(df.Department,df.Attrition).plot(kind='bar')

# %%
# pd.crosstab(df.Gender,df.Attrition).plot(kind='bar')

# %%
# pd.crosstab(df.MaritalStatus,df.Attrition).plot(kind='bar')

# %%
subdf = df.drop(['Id','Attrition','EmployeeNumber','Behaviour'],axis=1)
# Age
# DistanceFromHome
# Education
# EnvironmentSatisfaction
# JobInvolvement
# JobSatisfaction
# MonthlyIncome
# NumCompaniesWorked
# StockOptionLevel
# TotalWorkingYears
# TrainingTimesLastYear
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager
# CommunicationSkill
# JobRole
# BusinessTravel
# EducationField
# Department
# Gender 
# MaritalStatus
# OverTime

# %%
subdf.shape
# Out:
# (1628, 25)

# %%
# subdf.head()

# %%
business_dummies = pd.get_dummies(subdf.BusinessTravel,prefix='Travel').iloc[:,1:]
dept_dummies = pd.get_dummies(subdf.Department,prefix='Dept').iloc[:,1:]
edu_dummies = pd.get_dummies(subdf.EducationField,prefix='Edu').iloc[:,1:]
g_dummies = pd.get_dummies(subdf.Gender,prefix='g').iloc[:,1:]
job_dummies = pd.get_dummies(subdf.JobRole,prefix='j').iloc[:,1:]
mar_dummies = pd.get_dummies(subdf.MaritalStatus,prefix='mar').iloc[:,1:]
over_dummies = pd.get_dummies(subdf.OverTime,prefix='over').iloc[:,1:]

df_with_dummies = pd.concat([subdf,business_dummies,dept_dummies,edu_dummies,g_dummies,job_dummies,mar_dummies,over_dummies],axis='columns')
df_with_dummies.head()
# Out:
#    Age BusinessTravel              Department  DistanceFromHome  Education  \
# 0   30     Non-Travel  Research & Development                 2          3
# 1   36  Travel_Rarely  Research & Development                12          4
# 2   55  Travel_Rarely                   Sales                 2          1
# 3   39  Travel_Rarely  Research & Development                24          1
# 4   37  Travel_Rarely  Research & Development                 3          3
#
#   EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0        Medical                        3  Female               3
# 1  Life Sciences                        3  Female               3
# 2        Medical                        3    Male               3
# 3  Life Sciences                        1    Male               3
# 4          Other                        3    Male               3
#
#                   JobRole  ...  j_Laboratory Technician j_Manager  \
# ...

# %%
df_with_dummies=df_with_dummies.drop(['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime'],axis=1)
# df_with_dummies.columns

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# scaled_df = scaler.fit_transform(df_with_dummies)
# scaled_df = pd.DataFrame(scaled_df, columns=df_with_dummies.columns)
# scaled_df.head()

# %%
X=df_with_dummies
y=df.Attrition
X
# Out:
#       Age  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      30                 2          3                        3
# 1      36                12          4                        3
# 2      55                 2          1                        3
# 3      39                24          1                        1
# 4      37                 3          3                        3
# ...   ...               ...        ...                      ...
# 1623   42                19          3                        3
# 1624   55                 2          1                        3
# 1625   25                 9          2                        1
# 1626   29                13          3                        1
# 1627   29                18          1                        3
#
#       JobInvolvement  JobSatisfaction  MonthlyIncome  NumCompaniesWorked  \
# 0                  3                4           2564                   0
# ...

# %%
# from sklearn.linear_model import LinearRegression
# LR= LinearRegression()
# LR.fit(X,y)

# %%
test=pd.read_csv('test.csv')
test.head()
# Out:
#    Id  Age BusinessTravel              Department  DistanceFromHome  \
# 0   1   28  Travel_Rarely  Research & Development                 9
# 1   2   31  Travel_Rarely                   Sales                 6
# 2   3   37  Travel_Rarely  Research & Development                 6
# 3   4   42  Travel_Rarely  Research & Development                 1
# 4   5   45     Non-Travel  Research & Development                 4
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          3        Medical             377                        4    Male
# 1          4        Medical             653                        1    Male
# 2          3        Medical             474                        3    Male
# 3          2  Life Sciences             827                        4  Female
# 4          2  Life Sciences             972                        3    Male
#
#    ...  PerformanceRating StockOptionLevel  TotalWorkingYears  \
# ...

# %%
#cleaning test data
X_test=test.drop(['Id','EmployeeNumber','Behaviour'],axis=1)
business_dummies = pd.get_dummies(X_test.BusinessTravel,prefix='Travel').iloc[:,1:]
dept_dummies = pd.get_dummies(X_test.Department,prefix='Dept').iloc[:,1:]
edu_dummies = pd.get_dummies(X_test.EducationField,prefix='Edu').iloc[:,1:]
g_dummies = pd.get_dummies(X_test.Gender,prefix='g').iloc[:,1:]
job_dummies = pd.get_dummies(X_test.JobRole,prefix='j').iloc[:,1:]
mar_dummies = pd.get_dummies(X_test.MaritalStatus,prefix='mar').iloc[:,1:]
over_dummies = pd.get_dummies(X_test.OverTime,prefix='over').iloc[:,1:]

X_test_dummies = pd.concat([X_test,business_dummies,dept_dummies,edu_dummies,g_dummies,job_dummies,mar_dummies,over_dummies],axis='columns')
X_test_dummies=X_test_dummies.drop(['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime'],axis=1)

# %%
X_test_dummies.head()
# Out:
#    Age  DistanceFromHome  Education  EnvironmentSatisfaction  JobInvolvement  \
# 0   28                 9          3                        4               3
# 1   31                 6          4                        1               4
# 2   37                 6          3                        3               4
# 3   42                 1          2                        4               2
# 4   45                 4          2                        3               3
#
#    JobSatisfaction  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# 0                4           2070                   1                 23
# 1                4           5460                   4                 22
# 2                1           5974                   4                 13
# 3                4           6062                   9                 13
# 4                2           4447                   1                 12
#
# ...

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# scaled_df = scaler.fit_transform(X_test_dummies)
# scaled_df = pd.DataFrame(scaled_df, columns=X_test_dummies.columns)
# scaled_df.head()

# %%
# acc_log = round(LR.score(X, y) * 100, 2)
# acc_log

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# # Fit on training set only.
# scaler.fit(X)
# # Apply transform to both the training set and the test set.
# train = scaler.transform(X)
# test = scaler.transform(X_test_dummies)

# %%
# from sklearn.decomposition import PCA
# # Make an instance of the Model
# pca = PCA(.95)
# pca.fit(X)

# %%
# train=pca.transform(train)
# test=pca.transform(test)

# %%
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import chi2

# %%
# bestfeatures=SelectKBest(score_func=chi2,k=35)
# fit = bestfeatures.fit(X,y)
# dfscores = pd.DataFrame(fit.scores_)
# dfcolumns = pd.DataFrame(X.columns)

# %%
# featureScores = pd.concat([dfcolumns,dfscores],axis=1)
# featureScores.columns=['Specs','Score']

# %%
# features =featureScores.nlargest(35,'Score')
# new_columns=list(features.Specs)
# new_df=X[new_columns]
# new_df.columns
# new_test=X_test_dummies[new_columns]

# %%
# from sklearn.ensemble import RandomForestRegressor
# # n_estimators=200,max_depth=9,n_jobs=-1,random_state=1

# model=RandomForestRegressor(n_estimators=500)
# model.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=500, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
# Y_pred=model.predict(X_test_dummies)

# acc_log = round(model.score(X, y) * 100, 2)
# acc_log
# Out:
# 98.25

# %%
#Y_pred

# %%
from  sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
Y_pred=model.predict(X_test_dummies)

acc_log = round(model.score(X, y) * 100, 2)
acc_log
# Out:
# 100.0

# %%
submission = pd.DataFrame({
        "Id": test["Id"],
        "Attrition": Y_pred
    })
submission.to_csv('submission.csv', index=False)
